# %% [markdown]
# # CNN with memory
#
# This notebook provides a modified reimplementation of the previously tested CNN-based EEG classifiers:
#    - EEGNet by [Lawhern et al](http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta).
#       - Modifications to make it better suited for short-length windows
#       - Memory is added after the "feature extraction" layers, the CNN layers, in the form of a LSTM layer
#
# This notebook works in an offline fashion and uses epochs with a length of 3 seconds.
# This epoch starts 1 second before the visual queue was given, includes the 1 second the visual queue was shown and ends 1 second after the visual queue was hidden, totalling 3 seconds.
# No baseline correction was performed and the raw EEG data was used.
# The effective training and testing are done in a half-second window, starting 0.1 seconds after the start of the visual queue.
# A window of 0.5 seconds was chosen as it is a common size for sliding window approaches in online systems.
# Some alternatives to this setup were also considered, including one alternative performed for all experiment which uses a long, 1.5 seconds, window.
#
#
# Instructions on where to get the data are available on [the GitHub repository of the BCI master thesis project](https://www.github.com/pikawika/bci-master-thesis). These instructions are under `bci-master-thesis/code/data/CLA/README.md`. We will use the utility file `bci-master-thesis/code/utils/CLA_dataset.py` to work with this data. The data was stored as FIF files, which are included in [the GitHub repository of the BCI master thesis project](https://www.github.com/pikawika/bci-master-thesis).

# %% [markdown]
# <hr><hr>
#
# ## Table of Contents
#
# - Checking requirements
#    - Correct Anaconda environment
#    - Correct module access
#    - Correct file access
#    - Checking TensorFlow support
# - Same subject, same session: EEGNet bidirectional LSTM
# - Same subject, same session: EEGNet bidirectional ConvLSTM2D

# %% [markdown]
# <hr><hr>
#
# ## Checking requirements

# %% [markdown]
# ### Correct Anaconda environment
#
# The `bci-master-thesis` Anaconda environment should be active to ensure proper support. Installation instructions are available on [the GitHub repository of the BCI master thesis project](https://www.github.com/pikawika/bci-master-thesis).

# %%
####################################################
# CHECKING FOR RIGHT ANACONDA ENVIRONMENT
####################################################

import os
from platform import python_version
from pathlib import Path
from copy import copy

print(f"Active environment: {os.environ['CONDA_DEFAULT_ENV']}")
print(f"Correct environment: {os.environ['CONDA_DEFAULT_ENV'] == 'bci-master-thesis'}")
print(f"\nPython version: {python_version()}")
print(f"Correct Python version: {python_version() == '3.8.10'}")
# Out:
# Active environment: bci-master-thesis
# Correct environment: True
#
# Python version: 3.8.10
# Correct Python version: True

# %% [markdown]
# <hr>
#
# ### Correct module access
#
# The following code block will load in all required modules.

# %%
####################################################
# LOADING MODULES
####################################################

# allow reloading of libraries
import importlib

# Load util function file
import sys
sys.path.append('../utils')
import CLA_dataset
import TF_tools
importlib.reload(CLA_dataset)
importlib.reload(TF_tools)

# IO functions
from IPython.utils import io

# Set logging level for MNE before loading MNE
os.environ['MNE_LOGGING_LEVEL'] = 'WARNING'

# Modules tailored for EEG data
import mne; print(f"MNE version (1.0.2 recommended): {mne.__version__}")

# EEGNet model
import EEGModels_with_memory
from EEGModels_with_memory import EEGNet_bidirectional_lstm

# Data manipulation modules
import numpy as np; print(f"Numpy version (1.21.5 recommended): {np.__version__}")
import pandas as pd; print(f"Pandas version (1.4.1 recommended): {pd.__version__}")
import copy

# ML libraries
import sklearn;  print(f"Scikit-learn version (1.0.2 recommended): {sklearn.__version__}")
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score
from sklearn.preprocessing import OneHotEncoder

# Deep Learning libraries
import tensorflow as tf;  print(f"TensorFlow version (2.8.0 recommended): {tf.__version__}")

import keras; print(f"Keras version (2.8.0 recommended): {keras.__version__}")
from keras.callbacks import ModelCheckpoint

# Storing files
import pickle;  print(f"Pickle version (4.0 recommended): {pickle.format_version}")

# Plotting
import matplotlib; print(f"Matplotlib version (3.5.1 recommended): {matplotlib.__version__}")
import matplotlib.pyplot as plt
# Out:
# MNE version (1.0.2 recommended): 1.0.2
# Numpy version (1.21.5 recommended): 1.21.5
# Pandas version (1.4.1 recommended): 1.4.1
# Scikit-learn version (1.0.2 recommended): 1.0.2
# TensorFlow version (2.8.0 recommended): 2.8.0
# Keras version (2.8.0 recommended): 2.8.0
# Pickle version (4.0 recommended): 4.0
# Matplotlib version (3.5.1 recommended): 3.5.1

# %% [markdown]
# <hr>
#
# ### Correct file access
#
# As mentioned, this notebook uses a database provided by [Kaya et al](https://doi.org/10.1038/sdata.2018.211). The CLA dataset in particular. Instructions on where to get the data are available on [the GitHub repository of the BCI master thesis project](https://www.github.com/pikawika/bci-master-thesis). These instructions are under `bci-master-thesis/code/data/CLA/README.md`. The following code block checks if all required files are available.

# %%
####################################################
# CHECKING FILE ACCESS
####################################################

# Use util to determine if we have access
print("Full Matlab CLA file access: " + str(CLA_dataset.check_matlab_files_availability()))
print("Full MNE CLA file access: " + str(CLA_dataset.check_mne_files_availability()))
# Out:
# Full Matlab CLA file access: True
# Full MNE CLA file access: True

# %% [markdown]
# <hr>
#
# ### Checking TensorFlow support
#
# If you want to use TensorFlow with GPU acceleration, the below codeblock can help you gather insight.
#
# To launch the tensorboard use the following command in the `paper-notebooks` folder, be sure to have the right environments active:
# - Windows: `tensorboard --logdir=./logs/`
# - MacOS: `tensorboard --logdir='./logs/'`

# %%
TF_tools.check_tf_cpu_gpu_presence()
# Out:
# There are 1 CPUs available under the names:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
#
#
# There are not GPUs available.

# %% [markdown]
# <hr><hr>
#
# ## Same subject, same session: EEGNet bidirectional LSTM
#
# As discussed in the master's thesis, training and testing a classification system can happen using multiple strategies.
# A classifier may be trained on a singular subject, using a singular session and testing on that same session.
# This is an over-optimistic testing scenario and has a great risk of overfitting with poor generalisation to new sessions or new subjects but can be an okay baseline test to see if *at least something* can be learned.
# Just like we did for the CSP approaches, we do this for the EEGNet model as well.
#
#
# This experiment works as follows:
#    - We use participants with at least three recordings
#       - Participants: B, C, E
#       - NOTE: participant F has three files provided but one of those files has only three MI classes rather than three, hence it is not considered here
#    - We use the last recorded session of each of these participants, thus the one where the participant has the most experience
#    - We get epochs of 3 seconds, which includes one second before and after the visual queue
#       - We use only a half a second window taking into account the online system will use sliding windows.
#       - This window starts at 0.1 seconds after then visual queue and ends at 0.6 seconds after the visual queue
#    - We split the data in a train/test dataset with 20% test data balanced over all MI classes
#    - We use the parameters for EEGNet as found in the experimental notebook `6-DL-based-classification.ipynb`:
#       - We input the raw data, which is not baseline corrected, but multiply it by 1000000 to combat the scaling that MNE does per default.
#          - This means that we only use the data from the window, so it is easier adoptable to a live setting.
#       - We used the modified EEGNet model with memory provided through the `EEGModels_with_memory.py` util file with the following settings:
#          - nb_classes = 3 (int, number of classes to classify)
#          - Chans = 21 (number of channels in the EEG dat)
#          - Samples = 100 (number of time points in the EEG data - default: 128)
#          - dropoutRate = 0.5 (dropout fraction - default: 0.5)
#          - kernLength = 50 (length of temporal convolution in first layer. Suggested: half the sampling rate - default: 64)
#          - F1 = 8 (number of temporal filters - default: 8)
#          - F2 = 16 (number of pointwise filters - default: 16)
#          - D = 2 (number of spatial filters to learn within each temporal convolution - default: 2)
#          - norm_rate = 0.25 (Normalisation rate - default: 0.25)
#          - dropoutType = 'SpatialDropout2D' (Either SpatialDropout2D or Dropout, passed as a string - default: Dropout)
#       - We trained for 2500 epochs, saving the best model based on best validation accuracy and validation loss (0.25 validation split - equal size as true test split)
#    - We record the validation accuracy and loss over time for monitoring the training and test on the seperate test set

# %%
####################################################
# TRAINING EEGNET FOR EACH SUBJECT AND SESSION
####################################################

# Configure global parameters for all experiments
subject_ids_to_test = ["B", "C", "E"] # Subjects with three recordings
start_offset = -1 # One second before visual queue
end_offset = 1 # One second after visual queue
baseline = None # Baseline correction using data before the visual queue

do_experiment = True # Long experiment disabled per default

# Create the TensorFlow Keras model
keras_eegnet_model = EEGNet_bidirectional_lstm(
        nb_classes = 3, # int, number of classes to classify. 
        Chans = 21, # number of channels in the EEG data. 
        Samples = 100, # number of time points in the EEG data. (default: 128)
        dropoutRate = 0.5, # dropout fraction. (default: 0.5)
        kernLength = 50, # length of temporal convolution in first layer. Suggested: half the sampling rate. (default: 64)
        F1 = 8, # number of temporal filters. (default: 8)
        F2 = 16, # number of pointwise filters. (default: 16)
        D = 2, # number of spatial filters to learn within each temporal convolution. (default: 2)
        norm_rate = 0.25, # Normalisation rate. (default: 0.25)
        dropoutType = 'SpatialDropout2D', # Either SpatialDropout2D or Dropout, passed as a string. (default: Dropout)
        LSTM_size = 64 # Amount of units in LSTM layer
        )

if do_experiment:
        # Loop over all subjects and perform the grid search for finding the best parameters
        for subject_id in subject_ids_to_test[:1]:
                print("")
                print("####################################################")
                print(f"# TRAINING FOR SUBJECT {subject_id}")
                print("####################################################")
                print("")
                ###################### PREPARE DATA ######################
                
                with io.capture_output():
                        # Get MNE raw object for latest recording of that subject
                        mne_raw = CLA_dataset.get_last_raw_mne_data_for_subject(subject_id= subject_id)
                        
                        # Get epochs for that MNE raw
                        mne_epochs = CLA_dataset.get_usefull_epochs_from_raw(mne_raw,
                                                                             start_offset= start_offset,
                                                                             end_offset= end_offset,
                                                                             baseline= baseline)
                        
                        # Only keep epochs from the MI tasks
                        mne_epochs = mne_epochs['task/neutral', 'task/left', 'task/right']
                        
                        # Load epochs into memory
                        mne_epochs.load_data()
                
                # Get the labels
                labels = mne_epochs.events[:, -1]
                
                # Convert the labels to OHE labels as needed for Keras
                labels = labels.reshape(-1, 1)
                ohe = OneHotEncoder()
                labels = ohe.fit_transform(labels).toarray()
                
                # Get a half second window
                mne_epochs_data = mne_epochs.get_data(tmin= 0.1, tmax= 0.6)
                
                # Fix scaling sensitivity as MNE stores as data * 10e-6
                mne_epochs_data = mne_epochs_data * 1000000
                
                # Create a test and train split
                X_train, X_test, y_train, y_test = train_test_split(mne_epochs_data,
                                                                    labels,
                                                                    test_size = 0.2,
                                                                    shuffle= True,
                                                                    stratify= labels,                                                    
                                                                    random_state= 1998)
                
                # Store the train and test data so the best model can be retrained later
                with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/testdata-x.pickle", 'wb') as file:
                        pickle.dump(X_test, file)
                with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/testdata-y.pickle", 'wb') as file:
                        pickle.dump(y_test, file)
                with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/traindata-x.pickle", 'wb') as file:
                        pickle.dump(X_train, file)
                with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/traindata-y.pickle", 'wb') as file:
                        pickle.dump(y_train, file)
                        
                # Store the OHE encoder to enable same conversion later
                with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/ohe-encoder.pickle", 'wb') as file:
                        pickle.dump(ohe, file)
                        
                print(f"Shape of all data (epochs, channels, samples): {np.shape(mne_epochs_data)}")
                print(f"Shape of train data (epochs, channels, samples): {np.shape(X_train)}")
                print(f"Shape of test data (epochs, channels, samples): {np.shape(X_test)}")
                
                
                ###################### PREPARE MODEL ######################
                
                # Names for model
                best_base_model_filename = f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/trained_model" 
                tensorboard_name = f"paper-notebook7_eegnetlstm_singlesession_subject{subject_id}" # log name for tensorboard
                
                # Create copy of the model that needs training
                trained_model = keras.models.clone_model(keras_eegnet_model)
                
                # Compile the model so it can be fitted (loss and optimizer from EEGNet paper)
                trained_model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics=["accuracy"])
                
                # Train model with GPU
                # NOTE: change GPU to CPU if no GPU present
                with tf.device('/cpu:0'):
                        history = trained_model.fit(
                                x= X_train,
                                y= y_train,
                                batch_size= 128, # Default: 32
                                epochs= 500, # Default: 500 (EEGNet paper)
                                verbose= 1, # 0 = silent, 1 = progress bar, 2 = one line per epoch
                                callbacks= [TF_tools.tensorboard_callback(log_name= tensorboard_name),
                                            TF_tools.lowest_loss_model_save_callback(filepath= best_base_model_filename),
                                            TF_tools.highest_accuracy_model_save_callback(filepath= best_base_model_filename)],
                                validation_split= 0.25,
                                shuffle= True,
                                sample_weight= None, # Can be interesting due to time series
                                use_multiprocessing=True, # Done for faster speed
                                workers= 4 # Done for faster speed
                                )
                        
                # Store the fitting history
                with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/fitting_history.pickle", 'wb') as file:
                        pickle.dump(history.history, file)
                
                # Delete vars after singular experiment
                del mne_raw
                del mne_epochs
                del mne_epochs_data
                del trained_model
                del best_base_model_filename
                del tensorboard_name
                del labels
                del file
                del history
                del X_train
                del X_test
                del ohe
                del y_train
                del y_test
    
        # Delete vars after all experiments
        del subject_id
        
# Del global vars
del subject_ids_to_test
del baseline
del do_experiment
del end_offset
del start_offset
del keras_eegnet_model
# Out:
# ####################################################
# # TRAINING FOR SUBJECT B
# ####################################################
#
# Shape of all data (epochs, channels, samples): (960, 21, 100)
# Shape of train data (epochs, channels, samples): (768, 21, 100)
# Shape of test data (epochs, channels, samples): (192, 21, 100)
# Epoch 1/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0945 - accuracy: 0.3477
# Epoch 1: val_loss improved from inf to 1.09531, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 1: val_accuracy improved from -inf to 0.46875, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 5s 279ms/step - loss: 1.0947 - accuracy: 0.3542 - val_loss: 1.0953 - val_accuracy: 0.4688
# Epoch 2/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0920 - accuracy: 0.4395
# Epoch 2: val_loss improved from 1.09531 to 1.09320, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 2: val_accuracy did not improve from 0.46875
# 5/5 [==============================] - 0s 89ms/step - loss: 1.0925 - accuracy: 0.4288 - val_loss: 1.0932 - val_accuracy: 0.4688
# Epoch 3/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0882 - accuracy: 0.4453
# Epoch 3: val_loss improved from 1.09320 to 1.09076, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 3: val_accuracy improved from 0.46875 to 0.50000, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 87ms/step - loss: 1.0879 - accuracy: 0.4497 - val_loss: 1.0908 - val_accuracy: 0.5000
# Epoch 4/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0859 - accuracy: 0.4375
# Epoch 4: val_loss improved from 1.09076 to 1.08776, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 4: val_accuracy did not improve from 0.50000
# 5/5 [==============================] - 0s 83ms/step - loss: 1.0850 - accuracy: 0.4427 - val_loss: 1.0878 - val_accuracy: 0.4844
# Epoch 5/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0798 - accuracy: 0.4922
# Epoch 5: val_loss improved from 1.08776 to 1.08427, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 5: val_accuracy improved from 0.50000 to 0.53125, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 91ms/step - loss: 1.0792 - accuracy: 0.4965 - val_loss: 1.0843 - val_accuracy: 0.5312
# Epoch 6/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0738 - accuracy: 0.4824
# Epoch 6: val_loss improved from 1.08427 to 1.08025, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 6: val_accuracy did not improve from 0.53125
# 5/5 [==============================] - 0s 84ms/step - loss: 1.0731 - accuracy: 0.4826 - val_loss: 1.0802 - val_accuracy: 0.5312
# Epoch 7/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0664 - accuracy: 0.4746
# Epoch 7: val_loss improved from 1.08025 to 1.07595, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 7: val_accuracy improved from 0.53125 to 0.53646, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 92ms/step - loss: 1.0671 - accuracy: 0.4722 - val_loss: 1.0759 - val_accuracy: 0.5365
# Epoch 8/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0652 - accuracy: 0.4922
# Epoch 8: val_loss improved from 1.07595 to 1.07086, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 8: val_accuracy improved from 0.53646 to 0.56771, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 91ms/step - loss: 1.0641 - accuracy: 0.5017 - val_loss: 1.0709 - val_accuracy: 0.5677
# Epoch 9/500
# 5/5 [==============================] - ETA: 0s - loss: 1.0546 - accuracy: 0.5000
# Epoch 9: val_loss improved from 1.07086 to 1.06554, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 9: val_accuracy improved from 0.56771 to 0.57812, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 94ms/step - loss: 1.0546 - accuracy: 0.5000 - val_loss: 1.0655 - val_accuracy: 0.5781
# Epoch 10/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0452 - accuracy: 0.5078
# Epoch 10: val_loss improved from 1.06554 to 1.05993, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 10: val_accuracy did not improve from 0.57812
# 5/5 [==============================] - 0s 80ms/step - loss: 1.0450 - accuracy: 0.5174 - val_loss: 1.0599 - val_accuracy: 0.5729
# Epoch 11/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0300 - accuracy: 0.5625
# Epoch 11: val_loss improved from 1.05993 to 1.05440, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 11: val_accuracy did not improve from 0.57812
# 5/5 [==============================] - 0s 77ms/step - loss: 1.0315 - accuracy: 0.5556 - val_loss: 1.0544 - val_accuracy: 0.5729
# Epoch 12/500
# 5/5 [==============================] - ETA: 0s - loss: 1.0323 - accuracy: 0.5156
# Epoch 12: val_loss improved from 1.05440 to 1.04856, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 12: val_accuracy did not improve from 0.57812
# 5/5 [==============================] - 0s 104ms/step - loss: 1.0323 - accuracy: 0.5156 - val_loss: 1.0486 - val_accuracy: 0.5573
# Epoch 13/500
# 5/5 [==============================] - ETA: 0s - loss: 1.0232 - accuracy: 0.5590
# Epoch 13: val_loss improved from 1.04856 to 1.04175, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 13: val_accuracy did not improve from 0.57812
# 5/5 [==============================] - 1s 114ms/step - loss: 1.0232 - accuracy: 0.5590 - val_loss: 1.0417 - val_accuracy: 0.5521
# Epoch 14/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0159 - accuracy: 0.5254
# Epoch 14: val_loss improved from 1.04175 to 1.03376, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 14: val_accuracy did not improve from 0.57812
# 5/5 [==============================] - 0s 85ms/step - loss: 1.0144 - accuracy: 0.5365 - val_loss: 1.0338 - val_accuracy: 0.5729
# Epoch 15/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.0065 - accuracy: 0.5645
# Epoch 15: val_loss improved from 1.03376 to 1.02505, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 15: val_accuracy did not improve from 0.57812
# 5/5 [==============================] - 0s 83ms/step - loss: 1.0006 - accuracy: 0.5660 - val_loss: 1.0250 - val_accuracy: 0.5573
# Epoch 16/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9899 - accuracy: 0.5645
# Epoch 16: val_loss improved from 1.02505 to 1.01614, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 16: val_accuracy improved from 0.57812 to 0.60938, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 96ms/step - loss: 0.9862 - accuracy: 0.5747 - val_loss: 1.0161 - val_accuracy: 0.6094
# Epoch 17/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9770 - accuracy: 0.5723
# Epoch 17: val_loss improved from 1.01614 to 1.00624, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 17: val_accuracy improved from 0.60938 to 0.61458, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 91ms/step - loss: 0.9715 - accuracy: 0.5851 - val_loss: 1.0062 - val_accuracy: 0.6146
# Epoch 18/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9736 - accuracy: 0.5762
# Epoch 18: val_loss improved from 1.00624 to 0.99691, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 18: val_accuracy improved from 0.61458 to 0.64062, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 98ms/step - loss: 0.9718 - accuracy: 0.5781 - val_loss: 0.9969 - val_accuracy: 0.6406
# Epoch 19/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9542 - accuracy: 0.5996
# Epoch 19: val_loss improved from 0.99691 to 0.98613, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 19: val_accuracy improved from 0.64062 to 0.66146, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 102ms/step - loss: 0.9517 - accuracy: 0.6059 - val_loss: 0.9861 - val_accuracy: 0.6615
# Epoch 20/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9496 - accuracy: 0.5918
# Epoch 20: val_loss improved from 0.98613 to 0.97484, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 20: val_accuracy did not improve from 0.66146
# 5/5 [==============================] - 0s 89ms/step - loss: 0.9512 - accuracy: 0.5816 - val_loss: 0.9748 - val_accuracy: 0.6615
# Epoch 21/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9445 - accuracy: 0.6191
# Epoch 21: val_loss improved from 0.97484 to 0.96260, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 21: val_accuracy improved from 0.66146 to 0.68750, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 97ms/step - loss: 0.9435 - accuracy: 0.6198 - val_loss: 0.9626 - val_accuracy: 0.6875
# Epoch 22/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9168 - accuracy: 0.6230
# Epoch 22: val_loss improved from 0.96260 to 0.94905, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 22: val_accuracy improved from 0.68750 to 0.69271, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 100ms/step - loss: 0.9140 - accuracy: 0.6319 - val_loss: 0.9491 - val_accuracy: 0.6927
# Epoch 23/500
# 5/5 [==============================] - ETA: 0s - loss: 0.9205 - accuracy: 0.6267
# Epoch 23: val_loss improved from 0.94905 to 0.93534, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 23: val_accuracy improved from 0.69271 to 0.70312, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 1s 149ms/step - loss: 0.9205 - accuracy: 0.6267 - val_loss: 0.9353 - val_accuracy: 0.7031
# Epoch 24/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8939 - accuracy: 0.6465
# Epoch 24: val_loss improved from 0.93534 to 0.92112, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 24: val_accuracy improved from 0.70312 to 0.70833, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 92ms/step - loss: 0.8874 - accuracy: 0.6545 - val_loss: 0.9211 - val_accuracy: 0.7083
# Epoch 25/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8868 - accuracy: 0.6289
# Epoch 25: val_loss improved from 0.92112 to 0.90515, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 25: val_accuracy did not improve from 0.70833
# 5/5 [==============================] - 0s 82ms/step - loss: 0.8815 - accuracy: 0.6337 - val_loss: 0.9052 - val_accuracy: 0.7031
# Epoch 26/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8752 - accuracy: 0.6289
# Epoch 26: val_loss improved from 0.90515 to 0.89140, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 26: val_accuracy did not improve from 0.70833
# 5/5 [==============================] - 0s 82ms/step - loss: 0.8774 - accuracy: 0.6267 - val_loss: 0.8914 - val_accuracy: 0.7083
# Epoch 27/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8546 - accuracy: 0.6523
# Epoch 27: val_loss improved from 0.89140 to 0.87716, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 27: val_accuracy improved from 0.70833 to 0.71875, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 89ms/step - loss: 0.8609 - accuracy: 0.6458 - val_loss: 0.8772 - val_accuracy: 0.7188
# Epoch 28/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8410 - accuracy: 0.6934
# Epoch 28: val_loss improved from 0.87716 to 0.86467, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 28: val_accuracy improved from 0.71875 to 0.74479, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 91ms/step - loss: 0.8328 - accuracy: 0.6962 - val_loss: 0.8647 - val_accuracy: 0.7448
# Epoch 29/500
# 5/5 [==============================] - ETA: 0s - loss: 0.8396 - accuracy: 0.6684
# Epoch 29: val_loss improved from 0.86467 to 0.84993, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 29: val_accuracy did not improve from 0.74479
# 5/5 [==============================] - 1s 114ms/step - loss: 0.8396 - accuracy: 0.6684 - val_loss: 0.8499 - val_accuracy: 0.7448
# Epoch 30/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8220 - accuracy: 0.6777
# Epoch 30: val_loss improved from 0.84993 to 0.83584, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 30: val_accuracy improved from 0.74479 to 0.75000, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 1s 113ms/step - loss: 0.8194 - accuracy: 0.6753 - val_loss: 0.8358 - val_accuracy: 0.7500
# Epoch 31/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8181 - accuracy: 0.6758
# Epoch 31: val_loss improved from 0.83584 to 0.82195, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 31: val_accuracy improved from 0.75000 to 0.75521, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 89ms/step - loss: 0.8211 - accuracy: 0.6753 - val_loss: 0.8220 - val_accuracy: 0.7552
# Epoch 32/500
# 5/5 [==============================] - ETA: 0s - loss: 0.8060 - accuracy: 0.6840
# Epoch 32: val_loss improved from 0.82195 to 0.80965, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 32: val_accuracy improved from 0.75521 to 0.76562, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 1s 115ms/step - loss: 0.8060 - accuracy: 0.6840 - val_loss: 0.8097 - val_accuracy: 0.7656
# Epoch 33/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7970 - accuracy: 0.6806
# Epoch 33: val_loss improved from 0.80965 to 0.79582, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 33: val_accuracy did not improve from 0.76562
# 5/5 [==============================] - 1s 107ms/step - loss: 0.7970 - accuracy: 0.6806 - val_loss: 0.7958 - val_accuracy: 0.7552
# Epoch 34/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7738 - accuracy: 0.6934
# Epoch 34: val_loss improved from 0.79582 to 0.78195, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 34: val_accuracy did not improve from 0.76562
# 5/5 [==============================] - 0s 81ms/step - loss: 0.7706 - accuracy: 0.6962 - val_loss: 0.7820 - val_accuracy: 0.7604
# Epoch 35/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7978 - accuracy: 0.6771
# Epoch 35: val_loss improved from 0.78195 to 0.77345, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 35: val_accuracy did not improve from 0.76562
# 5/5 [==============================] - 1s 120ms/step - loss: 0.7978 - accuracy: 0.6771 - val_loss: 0.7735 - val_accuracy: 0.7500
# Epoch 36/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7666 - accuracy: 0.7101
# Epoch 36: val_loss improved from 0.77345 to 0.76381, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 36: val_accuracy did not improve from 0.76562
# 5/5 [==============================] - 1s 117ms/step - loss: 0.7666 - accuracy: 0.7101 - val_loss: 0.7638 - val_accuracy: 0.7604
# Epoch 37/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7693 - accuracy: 0.7049
# Epoch 37: val_loss improved from 0.76381 to 0.75406, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 37: val_accuracy did not improve from 0.76562
# 5/5 [==============================] - 0s 99ms/step - loss: 0.7693 - accuracy: 0.7049 - val_loss: 0.7541 - val_accuracy: 0.7604
# Epoch 38/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7461 - accuracy: 0.6953
# Epoch 38: val_loss improved from 0.75406 to 0.73890, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 38: val_accuracy did not improve from 0.76562
# 5/5 [==============================] - 1s 107ms/step - loss: 0.7568 - accuracy: 0.6858 - val_loss: 0.7389 - val_accuracy: 0.7656
# Epoch 39/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.7031
# Epoch 39: val_loss improved from 0.73890 to 0.73068, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 39: val_accuracy improved from 0.76562 to 0.77083, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 1s 125ms/step - loss: 0.7444 - accuracy: 0.7031 - val_loss: 0.7307 - val_accuracy: 0.7708
# Epoch 40/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7463 - accuracy: 0.7109
# Epoch 40: val_loss improved from 0.73068 to 0.72502, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 40: val_accuracy improved from 0.77083 to 0.77604, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 1s 116ms/step - loss: 0.7467 - accuracy: 0.7101 - val_loss: 0.7250 - val_accuracy: 0.7760
# Epoch 41/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7541 - accuracy: 0.7049
# Epoch 41: val_loss improved from 0.72502 to 0.71678, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 41: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 97ms/step - loss: 0.7541 - accuracy: 0.7049 - val_loss: 0.7168 - val_accuracy: 0.7760
# Epoch 42/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7374 - accuracy: 0.7014
# Epoch 42: val_loss improved from 0.71678 to 0.71139, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 42: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 95ms/step - loss: 0.7374 - accuracy: 0.7014 - val_loss: 0.7114 - val_accuracy: 0.7708
# Epoch 43/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7158 - accuracy: 0.7090
# Epoch 43: val_loss improved from 0.71139 to 0.70551, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 43: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 1s 99ms/step - loss: 0.7170 - accuracy: 0.7049 - val_loss: 0.7055 - val_accuracy: 0.7708
# Epoch 44/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7336 - accuracy: 0.6979
# Epoch 44: val_loss improved from 0.70551 to 0.69853, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 44: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 94ms/step - loss: 0.7336 - accuracy: 0.6979 - val_loss: 0.6985 - val_accuracy: 0.7604
# Epoch 45/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7456 - accuracy: 0.6973
# Epoch 45: val_loss improved from 0.69853 to 0.69070, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 45: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 88ms/step - loss: 0.7459 - accuracy: 0.6979 - val_loss: 0.6907 - val_accuracy: 0.7656
# Epoch 46/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7071 - accuracy: 0.7168
# Epoch 46: val_loss improved from 0.69070 to 0.68192, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 46: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 86ms/step - loss: 0.7094 - accuracy: 0.7170 - val_loss: 0.6819 - val_accuracy: 0.7708
# Epoch 47/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7229 - accuracy: 0.7051
# Epoch 47: val_loss improved from 0.68192 to 0.67756, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 47: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 93ms/step - loss: 0.7145 - accuracy: 0.7083 - val_loss: 0.6776 - val_accuracy: 0.7656
# Epoch 48/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7272 - accuracy: 0.6973
# Epoch 48: val_loss improved from 0.67756 to 0.67272, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 48: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 88ms/step - loss: 0.7266 - accuracy: 0.6927 - val_loss: 0.6727 - val_accuracy: 0.7656
# Epoch 49/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7154 - accuracy: 0.7170
# Epoch 49: val_loss improved from 0.67272 to 0.66588, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 49: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 96ms/step - loss: 0.7154 - accuracy: 0.7170 - val_loss: 0.6659 - val_accuracy: 0.7604
# Epoch 50/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6779 - accuracy: 0.7246
# Epoch 50: val_loss improved from 0.66588 to 0.66188, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 50: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6853 - accuracy: 0.7188 - val_loss: 0.6619 - val_accuracy: 0.7552
# Epoch 51/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6827 - accuracy: 0.7480
# Epoch 51: val_loss improved from 0.66188 to 0.65831, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 51: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 80ms/step - loss: 0.6863 - accuracy: 0.7448 - val_loss: 0.6583 - val_accuracy: 0.7604
# Epoch 52/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6628 - accuracy: 0.7383
# Epoch 52: val_loss improved from 0.65831 to 0.65497, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 52: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6779 - accuracy: 0.7309 - val_loss: 0.6550 - val_accuracy: 0.7604
# Epoch 53/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6914 - accuracy: 0.7207
# Epoch 53: val_loss improved from 0.65497 to 0.65345, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 53: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 79ms/step - loss: 0.7010 - accuracy: 0.7170 - val_loss: 0.6534 - val_accuracy: 0.7552
# Epoch 54/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6877 - accuracy: 0.7305
# Epoch 54: val_loss improved from 0.65345 to 0.65307, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 54: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 79ms/step - loss: 0.7026 - accuracy: 0.7222 - val_loss: 0.6531 - val_accuracy: 0.7708
# Epoch 55/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6937 - accuracy: 0.7324
# Epoch 55: val_loss did not improve from 0.65307
#
# Epoch 55: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6839 - accuracy: 0.7361 - val_loss: 0.6537 - val_accuracy: 0.7552
# Epoch 56/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6847 - accuracy: 0.7441
# Epoch 56: val_loss improved from 0.65307 to 0.65121, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 56: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 80ms/step - loss: 0.6734 - accuracy: 0.7535 - val_loss: 0.6512 - val_accuracy: 0.7760
# Epoch 57/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6722 - accuracy: 0.7441
# Epoch 57: val_loss improved from 0.65121 to 0.64413, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 57: val_accuracy did not improve from 0.77604
# 5/5 [==============================] - 0s 80ms/step - loss: 0.6622 - accuracy: 0.7517 - val_loss: 0.6441 - val_accuracy: 0.7708
# Epoch 58/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7108 - accuracy: 0.6953
# Epoch 58: val_loss improved from 0.64413 to 0.63712, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 58: val_accuracy improved from 0.77604 to 0.78125, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_highest_acc_model.hdf5
# 5/5 [==============================] - 0s 89ms/step - loss: 0.7139 - accuracy: 0.6979 - val_loss: 0.6371 - val_accuracy: 0.7812
# Epoch 59/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6672 - accuracy: 0.7402
# Epoch 59: val_loss improved from 0.63712 to 0.63434, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 59: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 79ms/step - loss: 0.6747 - accuracy: 0.7309 - val_loss: 0.6343 - val_accuracy: 0.7760
# Epoch 60/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6762 - accuracy: 0.7246
# Epoch 60: val_loss improved from 0.63434 to 0.62863, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 60: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6720 - accuracy: 0.7222 - val_loss: 0.6286 - val_accuracy: 0.7812
# Epoch 61/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6557 - accuracy: 0.7363
# Epoch 61: val_loss improved from 0.62863 to 0.62295, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 61: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6489 - accuracy: 0.7413 - val_loss: 0.6229 - val_accuracy: 0.7708
# Epoch 62/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6746 - accuracy: 0.7246
# Epoch 62: val_loss improved from 0.62295 to 0.62256, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 62: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 80ms/step - loss: 0.6729 - accuracy: 0.7205 - val_loss: 0.6226 - val_accuracy: 0.7760
# Epoch 63/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6521 - accuracy: 0.7305
# Epoch 63: val_loss improved from 0.62256 to 0.62008, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 63: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 79ms/step - loss: 0.6494 - accuracy: 0.7326 - val_loss: 0.6201 - val_accuracy: 0.7604
# Epoch 64/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6757 - accuracy: 0.7441
# Epoch 64: val_loss improved from 0.62008 to 0.61571, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 64: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 79ms/step - loss: 0.6757 - accuracy: 0.7378 - val_loss: 0.6157 - val_accuracy: 0.7604
# Epoch 65/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6530 - accuracy: 0.7441
# Epoch 65: val_loss did not improve from 0.61571
#
# Epoch 65: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6722 - accuracy: 0.7378 - val_loss: 0.6177 - val_accuracy: 0.7604
# Epoch 66/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6175 - accuracy: 0.7539
# Epoch 66: val_loss did not improve from 0.61571
#
# Epoch 66: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 70ms/step - loss: 0.6207 - accuracy: 0.7535 - val_loss: 0.6195 - val_accuracy: 0.7656
# Epoch 67/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6576 - accuracy: 0.7188
# Epoch 67: val_loss did not improve from 0.61571
#
# Epoch 67: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 70ms/step - loss: 0.6670 - accuracy: 0.7170 - val_loss: 0.6183 - val_accuracy: 0.7708
# Epoch 68/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6250 - accuracy: 0.7461
# Epoch 68: val_loss improved from 0.61571 to 0.61473, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 68: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6208 - accuracy: 0.7500 - val_loss: 0.6147 - val_accuracy: 0.7708
# Epoch 69/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6477 - accuracy: 0.7539
# Epoch 69: val_loss improved from 0.61473 to 0.61225, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 69: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6420 - accuracy: 0.7535 - val_loss: 0.6123 - val_accuracy: 0.7604
# Epoch 70/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6643 - accuracy: 0.7480
# Epoch 70: val_loss improved from 0.61225 to 0.60861, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 70: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6617 - accuracy: 0.7465 - val_loss: 0.6086 - val_accuracy: 0.7604
# Epoch 71/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6236 - accuracy: 0.7578
# Epoch 71: val_loss did not improve from 0.60861
#
# Epoch 71: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6407 - accuracy: 0.7431 - val_loss: 0.6091 - val_accuracy: 0.7500
# Epoch 72/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6121 - accuracy: 0.7832
# Epoch 72: val_loss did not improve from 0.60861
#
# Epoch 72: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6172 - accuracy: 0.7760 - val_loss: 0.6087 - val_accuracy: 0.7552
# Epoch 73/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6150 - accuracy: 0.7559
# Epoch 73: val_loss did not improve from 0.60861
#
# Epoch 73: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6418 - accuracy: 0.7378 - val_loss: 0.6090 - val_accuracy: 0.7708
# Epoch 74/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6567 - accuracy: 0.7324
# Epoch 74: val_loss did not improve from 0.60861
#
# Epoch 74: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 72ms/step - loss: 0.6666 - accuracy: 0.7309 - val_loss: 0.6105 - val_accuracy: 0.7656
# Epoch 75/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6226 - accuracy: 0.7754
# Epoch 75: val_loss improved from 0.60861 to 0.60837, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 75: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 80ms/step - loss: 0.6199 - accuracy: 0.7726 - val_loss: 0.6084 - val_accuracy: 0.7656
# Epoch 76/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6533 - accuracy: 0.7422
# Epoch 76: val_loss did not improve from 0.60837
#
# Epoch 76: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 73ms/step - loss: 0.6539 - accuracy: 0.7448 - val_loss: 0.6096 - val_accuracy: 0.7656
# Epoch 77/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6396 - accuracy: 0.7188
# Epoch 77: val_loss did not improve from 0.60837
#
# Epoch 77: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6429 - accuracy: 0.7188 - val_loss: 0.6125 - val_accuracy: 0.7604
# Epoch 78/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6408 - accuracy: 0.7539
# Epoch 78: val_loss did not improve from 0.60837
#
# Epoch 78: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6437 - accuracy: 0.7535 - val_loss: 0.6105 - val_accuracy: 0.7552
# Epoch 79/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6164 - accuracy: 0.7500
# Epoch 79: val_loss did not improve from 0.60837
#
# Epoch 79: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 73ms/step - loss: 0.6172 - accuracy: 0.7465 - val_loss: 0.6114 - val_accuracy: 0.7500
# Epoch 80/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6243 - accuracy: 0.7480
# Epoch 80: val_loss did not improve from 0.60837
#
# Epoch 80: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 72ms/step - loss: 0.6249 - accuracy: 0.7500 - val_loss: 0.6090 - val_accuracy: 0.7448
# Epoch 81/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6220 - accuracy: 0.7539
# Epoch 81: val_loss improved from 0.60837 to 0.60795, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 81: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6166 - accuracy: 0.7500 - val_loss: 0.6080 - val_accuracy: 0.7448
# Epoch 82/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6298 - accuracy: 0.7363
# Epoch 82: val_loss improved from 0.60795 to 0.60728, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 82: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6228 - accuracy: 0.7448 - val_loss: 0.6073 - val_accuracy: 0.7396
# Epoch 83/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6375 - accuracy: 0.7480
# Epoch 83: val_loss improved from 0.60728 to 0.60666, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 83: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6374 - accuracy: 0.7483 - val_loss: 0.6067 - val_accuracy: 0.7344
# Epoch 84/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6597 - accuracy: 0.7363
# Epoch 84: val_loss did not improve from 0.60666
#
# Epoch 84: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6633 - accuracy: 0.7292 - val_loss: 0.6067 - val_accuracy: 0.7500
# Epoch 85/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6174 - accuracy: 0.7598
# Epoch 85: val_loss improved from 0.60666 to 0.60391, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 85: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6238 - accuracy: 0.7552 - val_loss: 0.6039 - val_accuracy: 0.7500
# Epoch 86/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6180 - accuracy: 0.7480
# Epoch 86: val_loss improved from 0.60391 to 0.59826, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 86: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6264 - accuracy: 0.7431 - val_loss: 0.5983 - val_accuracy: 0.7552
# Epoch 87/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6337 - accuracy: 0.7539
# Epoch 87: val_loss improved from 0.59826 to 0.59077, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 87: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6340 - accuracy: 0.7517 - val_loss: 0.5908 - val_accuracy: 0.7656
# Epoch 88/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6151 - accuracy: 0.7656
# Epoch 88: val_loss did not improve from 0.59077
#
# Epoch 88: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 73ms/step - loss: 0.6024 - accuracy: 0.7726 - val_loss: 0.5934 - val_accuracy: 0.7708
# Epoch 89/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6118 - accuracy: 0.7734
# Epoch 89: val_loss did not improve from 0.59077
#
# Epoch 89: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6203 - accuracy: 0.7656 - val_loss: 0.5962 - val_accuracy: 0.7708
# Epoch 90/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6482 - accuracy: 0.7148
# Epoch 90: val_loss did not improve from 0.59077
#
# Epoch 90: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 74ms/step - loss: 0.6324 - accuracy: 0.7240 - val_loss: 0.5924 - val_accuracy: 0.7604
# Epoch 91/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6116 - accuracy: 0.7480
# Epoch 91: val_loss did not improve from 0.59077
#
# Epoch 91: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 74ms/step - loss: 0.6187 - accuracy: 0.7431 - val_loss: 0.5954 - val_accuracy: 0.7708
# Epoch 92/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6405 - accuracy: 0.7520
# Epoch 92: val_loss did not improve from 0.59077
#
# Epoch 92: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 74ms/step - loss: 0.6364 - accuracy: 0.7517 - val_loss: 0.6026 - val_accuracy: 0.7552
# Epoch 93/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6406 - accuracy: 0.7559
# Epoch 93: val_loss did not improve from 0.59077
#
# Epoch 93: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 73ms/step - loss: 0.6191 - accuracy: 0.7708 - val_loss: 0.5962 - val_accuracy: 0.7500
# Epoch 94/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6094 - accuracy: 0.7520
# Epoch 94: val_loss improved from 0.59077 to 0.58923, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 94: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6232 - accuracy: 0.7413 - val_loss: 0.5892 - val_accuracy: 0.7656
# Epoch 95/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.5952 - accuracy: 0.7598
# Epoch 95: val_loss did not improve from 0.58923
#
# Epoch 95: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 82ms/step - loss: 0.5902 - accuracy: 0.7622 - val_loss: 0.5905 - val_accuracy: 0.7552
# Epoch 96/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.5747 - accuracy: 0.7812
# Epoch 96: val_loss improved from 0.58923 to 0.58876, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 96: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 83ms/step - loss: 0.5930 - accuracy: 0.7726 - val_loss: 0.5888 - val_accuracy: 0.7552
# Epoch 97/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6299 - accuracy: 0.7480
# Epoch 97: val_loss improved from 0.58876 to 0.58462, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 97: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6319 - accuracy: 0.7465 - val_loss: 0.5846 - val_accuracy: 0.7656
# Epoch 98/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6081 - accuracy: 0.7500
# Epoch 98: val_loss improved from 0.58462 to 0.58043, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 98: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6080 - accuracy: 0.7535 - val_loss: 0.5804 - val_accuracy: 0.7760
# Epoch 99/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6011 - accuracy: 0.7637
# Epoch 99: val_loss improved from 0.58043 to 0.58001, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 99: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 81ms/step - loss: 0.5993 - accuracy: 0.7656 - val_loss: 0.5800 - val_accuracy: 0.7708
# Epoch 100/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6189 - accuracy: 0.7422
# Epoch 100: val_loss improved from 0.58001 to 0.57429, saving model to saved_variables/7/EEGNet_lstm/samesubject_samesession/subjectB/trained_model_lowest_loss_model.hdf5
#
# Epoch 100: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6135 - accuracy: 0.7483 - val_loss: 0.5743 - val_accuracy: 0.7656
# Epoch 101/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6416 - accuracy: 0.7305
# Epoch 101: val_loss did not improve from 0.57429
#
# Epoch 101: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6246 - accuracy: 0.7448 - val_loss: 0.5752 - val_accuracy: 0.7708
# Epoch 102/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6224 - accuracy: 0.7695
# Epoch 102: val_loss did not improve from 0.57429
#
# Epoch 102: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6127 - accuracy: 0.7691 - val_loss: 0.5807 - val_accuracy: 0.7656
# Epoch 103/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6474 - accuracy: 0.7480
# Epoch 103: val_loss did not improve from 0.57429
#
# Epoch 103: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 76ms/step - loss: 0.6380 - accuracy: 0.7535 - val_loss: 0.5865 - val_accuracy: 0.7760
# Epoch 104/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.5969 - accuracy: 0.7598
# Epoch 104: val_loss did not improve from 0.57429
#
# Epoch 104: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 83ms/step - loss: 0.5899 - accuracy: 0.7639 - val_loss: 0.5911 - val_accuracy: 0.7760
# Epoch 105/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.5966 - accuracy: 0.7656
# Epoch 105: val_loss did not improve from 0.57429
#
# Epoch 105: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6037 - accuracy: 0.7604 - val_loss: 0.5960 - val_accuracy: 0.7760
# Epoch 106/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6054 - accuracy: 0.7715
# Epoch 106: val_loss did not improve from 0.57429
#
# Epoch 106: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6082 - accuracy: 0.7674 - val_loss: 0.5969 - val_accuracy: 0.7552
# Epoch 107/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6064 - accuracy: 0.7637
# Epoch 107: val_loss did not improve from 0.57429
#
# Epoch 107: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 74ms/step - loss: 0.6052 - accuracy: 0.7639 - val_loss: 0.6022 - val_accuracy: 0.7656
# Epoch 108/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6021 - accuracy: 0.7559
# Epoch 108: val_loss did not improve from 0.57429
#
# Epoch 108: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 74ms/step - loss: 0.5994 - accuracy: 0.7587 - val_loss: 0.5958 - val_accuracy: 0.7656
# Epoch 109/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.5903 - accuracy: 0.7793
# Epoch 109: val_loss did not improve from 0.57429
#
# Epoch 109: val_accuracy did not improve from 0.78125
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6042 - accuracy: 0.7691 - val_loss: 0.5834 - val_accuracy: 0.7812
# Epoch 110/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6130 - accuracy: 0.7559
# ...
# Epoch 452/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.5017 - accuracy: 0.8145
# Epoch 452: val_loss did not improve from 0.52536
#
# Epoch 452: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4917 - accuracy: 0.8177 - val_loss: 0.5423 - val_accuracy: 0.8021
# Epoch 453/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4971 - accuracy: 0.8223
# Epoch 453: val_loss did not improve from 0.52536
#
# Epoch 453: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 86ms/step - loss: 0.4870 - accuracy: 0.8247 - val_loss: 0.5381 - val_accuracy: 0.8073
# Epoch 454/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4562 - accuracy: 0.8281
# Epoch 454: val_loss did not improve from 0.52536
#
# Epoch 454: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 83ms/step - loss: 0.4558 - accuracy: 0.8299 - val_loss: 0.5352 - val_accuracy: 0.7917
# Epoch 455/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4899 - accuracy: 0.8203
# Epoch 455: val_loss did not improve from 0.52536
#
# Epoch 455: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 85ms/step - loss: 0.4850 - accuracy: 0.8212 - val_loss: 0.5334 - val_accuracy: 0.7969
# Epoch 456/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4498 - accuracy: 0.8555
# Epoch 456: val_loss did not improve from 0.52536
#
# Epoch 456: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 87ms/step - loss: 0.4630 - accuracy: 0.8472 - val_loss: 0.5378 - val_accuracy: 0.7917
# Epoch 457/500
# 5/5 [==============================] - ETA: 0s - loss: 0.5157 - accuracy: 0.8038
# Epoch 457: val_loss did not improve from 0.52536
#
# Epoch 457: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 97ms/step - loss: 0.5157 - accuracy: 0.8038 - val_loss: 0.5400 - val_accuracy: 0.7969
# Epoch 458/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4691 - accuracy: 0.8299
# Epoch 458: val_loss did not improve from 0.52536
#
# Epoch 458: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4691 - accuracy: 0.8299 - val_loss: 0.5399 - val_accuracy: 0.8021
# Epoch 459/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4909 - accuracy: 0.8194
# Epoch 459: val_loss did not improve from 0.52536
#
# Epoch 459: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.4909 - accuracy: 0.8194 - val_loss: 0.5443 - val_accuracy: 0.8125
# Epoch 460/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.8299
# Epoch 460: val_loss did not improve from 0.52536
#
# Epoch 460: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 103ms/step - loss: 0.4557 - accuracy: 0.8299 - val_loss: 0.5501 - val_accuracy: 0.8073
# Epoch 461/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4820 - accuracy: 0.8125
# Epoch 461: val_loss did not improve from 0.52536
#
# Epoch 461: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 114ms/step - loss: 0.4820 - accuracy: 0.8125 - val_loss: 0.5544 - val_accuracy: 0.8073
# Epoch 462/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4423 - accuracy: 0.8420
# Epoch 462: val_loss did not improve from 0.52536
#
# Epoch 462: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4423 - accuracy: 0.8420 - val_loss: 0.5548 - val_accuracy: 0.8021
# Epoch 463/500
# 5/5 [==============================] - ETA: 0s - loss: 0.5019 - accuracy: 0.8142
# Epoch 463: val_loss did not improve from 0.52536
#
# Epoch 463: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 101ms/step - loss: 0.5019 - accuracy: 0.8142 - val_loss: 0.5497 - val_accuracy: 0.7917
# Epoch 464/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.8212
# Epoch 464: val_loss did not improve from 0.52536
#
# Epoch 464: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 113ms/step - loss: 0.4739 - accuracy: 0.8212 - val_loss: 0.5526 - val_accuracy: 0.7969
# Epoch 465/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.8333
# Epoch 465: val_loss did not improve from 0.52536
#
# Epoch 465: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 97ms/step - loss: 0.4638 - accuracy: 0.8333 - val_loss: 0.5514 - val_accuracy: 0.7917
# Epoch 466/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4415 - accuracy: 0.8368
# Epoch 466: val_loss did not improve from 0.52536
#
# Epoch 466: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 109ms/step - loss: 0.4415 - accuracy: 0.8368 - val_loss: 0.5528 - val_accuracy: 0.7917
# Epoch 467/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4665 - accuracy: 0.8403
# Epoch 467: val_loss did not improve from 0.52536
#
# Epoch 467: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4665 - accuracy: 0.8403 - val_loss: 0.5487 - val_accuracy: 0.7917
# Epoch 468/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8212
# Epoch 468: val_loss did not improve from 0.52536
#
# Epoch 468: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4803 - accuracy: 0.8212 - val_loss: 0.5450 - val_accuracy: 0.7865
# Epoch 469/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4878 - accuracy: 0.8125
# Epoch 469: val_loss did not improve from 0.52536
#
# Epoch 469: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 95ms/step - loss: 0.4878 - accuracy: 0.8125 - val_loss: 0.5445 - val_accuracy: 0.7969
# Epoch 470/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4844 - accuracy: 0.8108
# Epoch 470: val_loss did not improve from 0.52536
#
# Epoch 470: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4844 - accuracy: 0.8108 - val_loss: 0.5460 - val_accuracy: 0.7969
# Epoch 471/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.8281
# Epoch 471: val_loss did not improve from 0.52536
#
# Epoch 471: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4659 - accuracy: 0.8281 - val_loss: 0.5467 - val_accuracy: 0.8073
# Epoch 472/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4905 - accuracy: 0.8056
# Epoch 472: val_loss did not improve from 0.52536
#
# Epoch 472: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4905 - accuracy: 0.8056 - val_loss: 0.5472 - val_accuracy: 0.8073
# Epoch 473/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.8472
# Epoch 473: val_loss did not improve from 0.52536
#
# Epoch 473: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 110ms/step - loss: 0.4537 - accuracy: 0.8472 - val_loss: 0.5480 - val_accuracy: 0.7917
# Epoch 474/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4683 - accuracy: 0.8299
# Epoch 474: val_loss did not improve from 0.52536
#
# Epoch 474: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4683 - accuracy: 0.8299 - val_loss: 0.5454 - val_accuracy: 0.7708
# Epoch 475/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4485 - accuracy: 0.8368
# Epoch 475: val_loss did not improve from 0.52536
#
# Epoch 475: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 110ms/step - loss: 0.4485 - accuracy: 0.8368 - val_loss: 0.5392 - val_accuracy: 0.7917
# Epoch 476/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4849 - accuracy: 0.8160
# Epoch 476: val_loss did not improve from 0.52536
#
# Epoch 476: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4849 - accuracy: 0.8160 - val_loss: 0.5332 - val_accuracy: 0.8073
# Epoch 477/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4736 - accuracy: 0.8333
# Epoch 477: val_loss did not improve from 0.52536
#
# Epoch 477: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4736 - accuracy: 0.8333 - val_loss: 0.5320 - val_accuracy: 0.8021
# Epoch 478/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4457 - accuracy: 0.8333
# Epoch 478: val_loss did not improve from 0.52536
#
# Epoch 478: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 97ms/step - loss: 0.4457 - accuracy: 0.8333 - val_loss: 0.5295 - val_accuracy: 0.8021
# Epoch 479/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.8108
# Epoch 479: val_loss did not improve from 0.52536
#
# Epoch 479: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 109ms/step - loss: 0.4876 - accuracy: 0.8108 - val_loss: 0.5291 - val_accuracy: 0.7865
# Epoch 480/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4643 - accuracy: 0.8316
# Epoch 480: val_loss did not improve from 0.52536
#
# Epoch 480: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4643 - accuracy: 0.8316 - val_loss: 0.5349 - val_accuracy: 0.7917
# Epoch 481/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4624 - accuracy: 0.8403
# Epoch 481: val_loss did not improve from 0.52536
#
# Epoch 481: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 95ms/step - loss: 0.4624 - accuracy: 0.8403 - val_loss: 0.5384 - val_accuracy: 0.7865
# Epoch 482/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4392 - accuracy: 0.8472
# Epoch 482: val_loss did not improve from 0.52536
#
# Epoch 482: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4392 - accuracy: 0.8472 - val_loss: 0.5393 - val_accuracy: 0.7917
# Epoch 483/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4608 - accuracy: 0.8351
# Epoch 483: val_loss did not improve from 0.52536
#
# Epoch 483: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 96ms/step - loss: 0.4608 - accuracy: 0.8351 - val_loss: 0.5456 - val_accuracy: 0.7969
# Epoch 484/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4842 - accuracy: 0.8264
# Epoch 484: val_loss did not improve from 0.52536
#
# Epoch 484: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 96ms/step - loss: 0.4842 - accuracy: 0.8264 - val_loss: 0.5512 - val_accuracy: 0.7917
# Epoch 485/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.8368
# Epoch 485: val_loss did not improve from 0.52536
#
# Epoch 485: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 96ms/step - loss: 0.4545 - accuracy: 0.8368 - val_loss: 0.5476 - val_accuracy: 0.8021
# Epoch 486/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4778 - accuracy: 0.8333
# Epoch 486: val_loss did not improve from 0.52536
#
# Epoch 486: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 95ms/step - loss: 0.4778 - accuracy: 0.8333 - val_loss: 0.5425 - val_accuracy: 0.7917
# Epoch 487/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.8229
# Epoch 487: val_loss did not improve from 0.52536
#
# Epoch 487: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4705 - accuracy: 0.8229 - val_loss: 0.5407 - val_accuracy: 0.7760
# Epoch 488/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4651 - accuracy: 0.8316
# Epoch 488: val_loss did not improve from 0.52536
#
# Epoch 488: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 97ms/step - loss: 0.4651 - accuracy: 0.8316 - val_loss: 0.5441 - val_accuracy: 0.7917
# Epoch 489/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4682 - accuracy: 0.8229
# Epoch 489: val_loss did not improve from 0.52536
#
# Epoch 489: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 102ms/step - loss: 0.4682 - accuracy: 0.8229 - val_loss: 0.5471 - val_accuracy: 0.8125
# Epoch 490/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4699 - accuracy: 0.8264
# Epoch 490: val_loss did not improve from 0.52536
#
# Epoch 490: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4699 - accuracy: 0.8264 - val_loss: 0.5482 - val_accuracy: 0.8073
# Epoch 491/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4505 - accuracy: 0.8455
# Epoch 491: val_loss did not improve from 0.52536
#
# Epoch 491: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 108ms/step - loss: 0.4505 - accuracy: 0.8455 - val_loss: 0.5477 - val_accuracy: 0.8073
# Epoch 492/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4769 - accuracy: 0.8194
# Epoch 492: val_loss did not improve from 0.52536
#
# Epoch 492: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 97ms/step - loss: 0.4769 - accuracy: 0.8194 - val_loss: 0.5502 - val_accuracy: 0.7969
# Epoch 493/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4645 - accuracy: 0.8368
# Epoch 493: val_loss did not improve from 0.52536
#
# Epoch 493: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 107ms/step - loss: 0.4645 - accuracy: 0.8368 - val_loss: 0.5591 - val_accuracy: 0.7865
# Epoch 494/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4768 - accuracy: 0.8229
# Epoch 494: val_loss did not improve from 0.52536
#
# Epoch 494: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4768 - accuracy: 0.8229 - val_loss: 0.5563 - val_accuracy: 0.7865
# Epoch 495/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.8299
# Epoch 495: val_loss did not improve from 0.52536
#
# Epoch 495: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 96ms/step - loss: 0.4641 - accuracy: 0.8299 - val_loss: 0.5579 - val_accuracy: 0.7865
# Epoch 496/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.8160
# Epoch 496: val_loss did not improve from 0.52536
#
# Epoch 496: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4792 - accuracy: 0.8160 - val_loss: 0.5592 - val_accuracy: 0.7865
# Epoch 497/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8212
# Epoch 497: val_loss did not improve from 0.52536
#
# Epoch 497: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4654 - accuracy: 0.8212 - val_loss: 0.5643 - val_accuracy: 0.7812
# Epoch 498/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4643 - accuracy: 0.8351
# Epoch 498: val_loss did not improve from 0.52536
#
# Epoch 498: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4643 - accuracy: 0.8351 - val_loss: 0.5733 - val_accuracy: 0.7760
# Epoch 499/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.8490
# Epoch 499: val_loss did not improve from 0.52536
#
# Epoch 499: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 97ms/step - loss: 0.4537 - accuracy: 0.8490 - val_loss: 0.5748 - val_accuracy: 0.7708
# Epoch 500/500
# 5/5 [==============================] - ETA: 0s - loss: 0.4436 - accuracy: 0.8438
# Epoch 500: val_loss did not improve from 0.52536
#
# Epoch 500: val_accuracy did not improve from 0.81250
# 5/5 [==============================] - 0s 95ms/step - loss: 0.4436 - accuracy: 0.8438 - val_loss: 0.5760 - val_accuracy: 0.7708

# %% [markdown]
# #### Results
#
# EEGNet:
#
# | **Subject** | **EEGNet: best validation accuracy** | **EEGNet: best validation loss** | **EEGNet: test split accuracy (best acc model)** | **EEGNet: test split accuracy (best loss model)** |
# |-------------|--------------------------------------|----------------------------------|--------------------------------------------------|---------------------------------------------------|
# | B           | 0.8333 @ epoch 1262                  | 0.4747 @ epoch 1959              | 0.7656                                           | 0.7708                                            |
# | C           | 0.9167 @ epoch 2497                  | 0.3088 @ epoch 1653              | 0.8906                                           | 0.8906                                            |
# | E           | 0.9215 @ epoch 1010                  | 0.2724 @ epoch 981               | 0.8586                                           | 0.8691                                            |
#
# EEGNet with biderectional LSTM:
#
# | **Subject** | **EEGNet: best validation accuracy** | **EEGNet: best validation loss** | **EEGNet: test split accuracy (best acc model)** | **EEGNet: test split accuracy (best loss model)** |
# |-------------|--------------------------------------|----------------------------------|--------------------------------------------------|---------------------------------------------------|
# | B           | 0.8125 @ epoch 214                   | 0.5254 @ epoch 439               | 0.7812                                           | 0.776                                             |
# | C           | xxx                                  | xxx                              | xxx                                              | xxx                                               |
# | E           | xxx                                  | xxx                              | xxx                                              | xxx                                               |

# %%
####################################################
# RESULTS
####################################################

# Configure global parameters for all experiments
subject_ids_to_test = ["B", "C", "E"] # Subjects with three recordings

# Loop over all found results
for subject_id in subject_ids_to_test[:1]:
    print()
    print("####################################################")
    print(f"# RESULTS FOR SUBJECT {subject_id}")
    print("####################################################")
    print()
    
    ################### load data ###################
    # Names for model
    best_base_model_filename = f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/trained_model"
    
    # Open models from file
    lowest_loss_model = TF_tools.load_lowest_loss_model(filepath= best_base_model_filename)
    highest_accuracy_model = TF_tools.load_highest_accuracy_model(filepath= best_base_model_filename)
    
    # Get data from files
    with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/testdata-x.pickle", 'rb') as f:
        X_test = pickle.load(f)
    with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/testdata-y.pickle", 'rb') as f:
        y_test = pickle.load(f)
        
    # Get OHE from file
    with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/ohe-encoder.pickle", 'rb') as f:
        ohe = pickle.load(f)
        
    # Get history from file
    with open(f"saved_variables/7/EEGNet_lstm/samesubject_samesession/subject{subject_id}/fitting_history.pickle", 'rb') as f:
        history = pickle.load(f)
        
    # Convert OHE labels back to true labels
    y_test = ohe.inverse_transform(y_test)
    
    ################### history stats ###################
    print("#### results of training ####")
    print(f"Best training accuracy (max) {np.round(np.max(history['accuracy']), 4)} @ epoch {np.argmax(history['accuracy']) + 1}")
    print(f"Best training loss (min) {np.round(np.min(history['loss']), 4)} @ epoch {np.argmin(history['loss']) + 1}")
    print()
    print(f"Best validation accuracy (max) {np.round(np.max(history['val_accuracy']), 4)} @ epoch {np.argmax(history['val_accuracy']) + 1}")
    print(f"Best validation loss (min) {np.round(np.min(history['val_loss']), 4)} @ epoch {np.argmin(history['val_loss']) + 1}")
    
    ################### highest accuracy model ###################
    print("\n#### results for highest accuracy model ####")
    # Get predictions from lowest loss model and convert back to labels
    y_pred = highest_accuracy_model.predict(X_test)
    y_pred = ohe.inverse_transform(y_pred)
    
    # Get accuracy score and print it
    accuracy =  accuracy_score(y_test, y_pred)
    print(f"Accuracy of: {np.round(accuracy, 4)}")
    
    # Show CM
    ConfusionMatrixDisplay.from_predictions(y_true= y_test, y_pred= y_pred)
    plt.show()
    
    ################### lowest loss model ###################
    print("\n#### results for lowest loss model ####")
    # Get predictions from lowest loss model and convert back to labels
    y_pred = lowest_loss_model.predict(X_test)
    y_pred = ohe.inverse_transform(y_pred)
    
    # Get accuracy score and print it
    accuracy =  accuracy_score(y_test, y_pred)
    print(f"Accuracy of: {np.round(accuracy, 4)}")
    
    # Show CM
    ConfusionMatrixDisplay.from_predictions(y_true= y_test, y_pred= y_pred)
    plt.show()
    
    ################### cleanup ###################
    # remove unused vars
    del best_base_model_filename
    del lowest_loss_model
    del highest_accuracy_model
    del f
    del X_test
    del y_test
    del history
    del ohe
    del y_pred
    del accuracy

# Remove unsused variables
del subject_ids_to_test
del subject_id
# Out:
# ####################################################
# # RESULTS FOR SUBJECT B
# ####################################################
#
# #### results of training ####
# Best training accuracy (max) 0.8611 @ epoch 432
# Best training loss (min) 0.4257 @ epoch 432
#
# Best validation accuracy (max) 0.8125 @ epoch 214
# Best validation loss (min) 0.5254 @ epoch 439
#
# #### results for highest accuracy model ####
# Accuracy of: 0.7812
# #### results for lowest loss model ####
# Accuracy of: 0.776
